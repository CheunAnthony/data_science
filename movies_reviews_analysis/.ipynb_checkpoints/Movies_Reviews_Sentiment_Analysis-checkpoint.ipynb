# %% [markdown]
# # **Movies Revieew Analysis**
#
# **Overview:**
#
# In this project, I built a sentiment analysis model to classify text into positive, negative, or neutral categories. I specifically used the IMDb Movie Reviews dataset, which contains 50,000 movie reviews labeled as positive or negative. This dataset is a popular choice for sentiment analysis tasks because of its balanced nature and variety of language used in the reviews.

# %% [markdown]
#  __Table of Contents__
#
#  <ol>
#     <li>
#         <a href="#Libraries">Importing Required Libraries</a>
#     </li>
#     <li>
#         <a href="#Data Exploration">Data Exploration</a>
#         <ol>
#             <li><a href="#Verification">Checking Null and Duplicates Values</a></li>
#             <li><a href="#Sentiment Distribution">Sentiment Distribution</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Text Preprocessing">Text Preprocessing</a>
#         <ol>
#             <li><a href="###Download Required Libraries">Download Required Libraries</a></li>
#             <li><a href="###Tokenization and Stopword Removal">Tokenization and Stopword Removal</a></li>
#             <li><a href="###Top N-grams">Top N-grams</a></li>
#             <li><a href="###Label Encoding">Label Encoding</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Models">Models</a>
#         <ol>
#             <li><a href="###XGBoost">XGBoost</a></li>
#             <li><a href="###Bidirectional Long Short-Term Memory">Bidirectional Long Short-Term Memory</a></li>
#         </ol>
#     </li>
# </ol>

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mticker
from wordcloud import WordCloud

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import (
    accuracy_score, precision_recall_fscore_support, roc_auc_score,
    precision_recall_curve, roc_curve, auc, confusion_matrix,
    classification_report, brier_score_loss
)
from sklearn.utils import Bunch
from joblib import dump


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras import regularizers
from keras.layers import BatchNormalization
from keras.callbacks import ReduceLROnPlateau
#from tensorflow.keras.layers import CuDNNLSTM
import xgboost as xgb

# %% [markdown]
# # Load Our Dataset

# %%
movies_df = pd.read_csv('movies_dataset/IMDB_Dataset.csv')

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Showing Our Dataset Shape

# %%
movies_df.shape
# Out:
# (50000, 2)

# %% [markdown]
# # Verification
#
# * Checking Null Values
# * Checking Duplicates Values

# %%
movies_df.isna().sum().sum()
# Out:
# 0

# %%
movies_df[movies_df.duplicated()].shape
# Out:
# (418, 2)

# %%
duplicates_df = movies_df[movies_df.duplicated()]

# %%
duplicates_df.head()
# Out:
#                                                  review sentiment
# 3537  Quite what the producers of this appalling ada...  negative
# 3769  My favourite police series of all time turns t...  positive
# 4391  Beautiful film, pure Cassavetes style. Gena Ro...  positive
# 6352  If you liked the Grinch movie... go watch that...  negative
# 6479  I want very much to believe that the above quo...  negative

# %% [markdown]
# # Sentiment Distribution

# %%
palette = ['#66BB6A', '#D50000']
ax = sns.countplot(data=movies_df, x="sentiment",hue="sentiment",palette=palette)
ax.bar_label(ax.containers[0])
plt.title("Sentiment Distribution", fontsize=13)
plt.show()

# %% [markdown]
# # Text Preprocessing
#
# * Remove HTML Tags
# * Remove Punctuations
# * Remove Numbers
# * Remove Stopwords
# * Convert Test To Lower Case

# %%
def clean_text(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    text = re.sub(r'[^A-Za-z\s]', '', text)
    return text.lower().strip()

# %% [markdown]
# ### Download Required Libraries

# %%
nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Tokenization and Stopword Removal

# %%
movies_df['clean_review'] = movies_df['review'].apply(lambda x: ' '.join(
    [word for word in nltk.word_tokenize(clean_text(x)) if word not in stop_words]))

# %%
movies_df.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         clean_review
# 0  one reviewers mentioned watching oz episode yo...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically theres family little boy jake thinks...
# 4  petter matteis love time money visually stunni...

# %%
movies_df['len_tokens'] = movies_df['clean_review'].str.split().apply(len)
movies_df['len_chars'] = movies_df["clean_review"].str.len()

# %%
movies_df.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                         clean_review  len_tokens  len_chars
# 0  one reviewers mentioned watching oz episode yo...         167       1157
# 1  wonderful little production filming technique ...          84        656
# 2  thought wonderful way spend time hot summer we...          85        587
# 3  basically theres family little boy jake thinks...          66        456
# 4  petter matteis love time money visually stunni...         125        863

# %% [markdown]
# ### Review Length Distribution

# %%
plt.figure(figsize=(8,4))
sns.histplot(movies_df["len_tokens"], bins=50, kde=True, color="#3498db")
plt.title("Clean Review Length (Tokens)", fontsize=12, weight="bold")
plt.xlabel("Number of Tokens")
plt.ylabel("Frequency")
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot By Sentiment

# %%
plt.figure(figsize=(8,4))
sns.boxplot(data=movies_df, x="sentiment",hue="sentiment", y="len_tokens", palette=palette)
plt.title("Review Length by Sentiment", fontsize=13, weight="bold")
plt.xlabel("Sentiment")
plt.ylabel("Number of Tokens")
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation

# %%
sns.scatterplot(data=movies_df,x='len_chars',y='len_tokens')
plt.title('Correlation between length of chars and length of tokens')
plt.show()

# %% [markdown]
# ### WordClouds
#
# We used WordClouds text analysis and visualization to quickly and intuitively understand the main themes or topics in a body of text. WordCloud visually represents the most frequent words in a text — the larger or bolder a word appears, the more often it occurs

# %%
review_pos = " ".join(movies_df.loc[movies_df.sentiment == "positive", "clean_review"]) 
review_neg = " ".join(movies_df.loc[movies_df.sentiment == "negative", "clean_review"])

wc_pos = WordCloud(
    width=900, height=500, background_color="white", colormap="Greens",
    max_words=100, min_font_size=10
).generate(review_pos)


wc_neg = WordCloud(
    width=900, height=500, background_color="white", colormap="Reds",
    max_words=100, min_font_size=10
).generate(review_neg)


fig, ax = plt.subplots(1, 2, figsize=(14, 6))
ax[0].imshow(wc_pos, interpolation="bilinear")
ax[0].axis("off")
ax[0].set_title("WordCloud — Positive Reviews", fontsize=13, weight="bold")


ax[1].imshow(wc_neg, interpolation="bilinear")
ax[1].axis("off")
ax[1].set_title("WordCloud — Negative Reviews", fontsize=13, weight="bold")



plt.tight_layout()
sns.despine()
plt.show()

# %% [markdown]
# ### Top N-grams

# %%
def top_ngrams(corpus, ngram_range=(1,1), top_k=15, min_df=5, max_df=0.9):
    
    vec = CountVectorizer(
        ngram_range=ngram_range,
        min_df=min_df,
        max_df=max_df,
        stop_words="english")
    
    X = vec.fit_transform(corpus)
    total = np.asarray(X.sum(axis=0)).ravel()
    vocab = np.array(vec.get_feature_names_out())
    idx = np.argsort(total)[::-1][:top_k]
    return pd.DataFrame({"term": vocab[idx], "count": total[idx]})

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
pos_review = top_ngrams(movies_df.loc[movies_df.sentiment == "positive", "clean_review"], (1,1))
neg_review = top_ngrams(movies_df.loc[movies_df.sentiment == "negative", "clean_review"], (1,1))

sns.barplot(data=pos_review, x="count", y="term", ax=axes[0], color="#2ecc71")
axes[0].set_title("Top Unigrams — Positive", fontsize=13, weight="bold")
axes[0].set_xlabel("Frequency"); axes[0].set_ylabel("Term")

sns.barplot(data=neg_review, x="count", y="term", ax=axes[1], color="#e74c3c")
axes[1].set_title("Top Unigrams — Negative", fontsize=13, weight="bold")
axes[1].set_xlabel("Frequency"); axes[1].set_ylabel("")

plt.tight_layout()
sns.despine()
plt.show()

# %% [markdown]
# ### Label Encoding
#
# *  Encode Sentiment Feature

# %% [markdown]
# ### Split Our Dataset

# %%
label_encoder = LabelEncoder()
movies_df['encoded_sentiment'] = label_encoder.fit_transform(movies_df['sentiment'])

# %%
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'negative': 0, 'positive': 1}

# %%
x = movies_df['clean_review']
y = movies_df['encoded_sentiment']

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ### TF-IDF Vectorization

# %%
tfidf = TfidfVectorizer(
    max_features=60000,
    ngram_range=(1, 2),
    min_df=3,
    max_df=0.9,
    stop_words="english",
    dtype=np.float32
)

# %%
x_train_vec = tfidf.fit_transform(x_train)
x_test_vec = tfidf.transform(x_test)

# %%
print(f"Train shape: {x_train_vec.shape}  |  Test shape: {x_test_vec.shape}")
print(f"Vocabulary size: {len(tfidf.get_feature_names_out()):,}")
# Out:
# Train shape: (40000, 60000)  |  Test shape: (10000, 60000)
# Vocabulary size: 60,000

# %% [markdown]
# ### Models
#
# * Bidirectional LSTM
# * XGBoost

# %% [markdown]
# ### XGBoost

# %%
num_classes = len(np.unique(y_train))
xgb_model = xgb.XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    use_label_encoder=False,
    objective='multi:softprob',
    eval_metric='mlogloss',
    random_state=42,
    num_class=num_classes
)

# %%
results = {}
xgb_model.fit(
    x_train_vec,
    y_train,
    eval_set=[(x_train_vec, y_train), (x_test_vec, y_test)],
    verbose=False
)
# Out:
# C:\Users\HP\anaconda3\envs\smart\lib\site-packages\xgboost\core.py:158: UserWarning: [01:47:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
# ...

# %%
evals_result = xgb_model.evals_result()
train_loss = evals_result['validation_0']['mlogloss']
val_loss = evals_result['validation_1']['mlogloss']

plt.figure(figsize=(8,5))
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('XGBoost Training vs Validation Loss')
plt.xlabel('Iterations')
plt.ylabel('Log Loss')
plt.legend()
plt.show()

# %%
y_pred_xgb = xgb_model.predict(x_test_vec)

print("XGBoost Accuracy:", accuracy_score(y_test, np.argmax(y_pred_xgb, axis=1)))
print(classification_report(y_test, np.argmax(y_pred_xgb, axis=1)))
# Out:
# XGBoost Accuracy: 0.8466
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      5000
#            1       0.83      0.88      0.85      5000
#
#     accuracy                           0.85     10000
#    macro avg       0.85      0.85      0.85     10000
# weighted avg       0.85      0.85      0.85     10000

# %% [markdown]
# ### XGBoost Confusion Matix

# %%
cm = confusion_matrix(y_test, np.argmax(y_pred_xgb, axis=1))
sns.heatmap(cm, annot=True, fmt='d')
plt.title("XGBoost Confusion Matrix")
plt.show()

# %% [markdown]
# ### Bidirectional Long Short-Term Memory

# %%
MAX_WORDS = 30000
MAX_LEN   = 150

tok = Tokenizer(num_words=MAX_WORDS, oov_token="<OOV>")
tok.fit_on_texts(x_train)
xtr = pad_sequences(tok.texts_to_sequences(x_train), maxlen=MAX_LEN, padding="post", truncating="post")
xte = pad_sequences(tok.texts_to_sequences(x_test),  maxlen=MAX_LEN, padding="post", truncating="post")

# %%
bilstm_model = Sequential([
    Embedding(input_dim=MAX_WORDS,output_dim=64,input_length=MAX_LEN),
    Bidirectional(LSTM(32,dropout=0.4,recurrent_dropout=0.4,kernel_regularizer=regularizers.l2(0.01),recurrent_regularizer=regularizers.l2(0.01))),
    Dropout(0.4),
    Dense(16,activation='relu',kernel_regularizer=regularizers.l2(0.01)),
    #BatchNormalization(),
    Dropout(0.4),
    Dense(1,activation='sigmoid')
])
bilstm_model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
early_stop = EarlyStopping(
monitor='val_loss',
patience=3,
restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)

# %%
history = bilstm_model.fit(
        xtr, y_train,
        validation_split=0.2,
        epochs=10,
        batch_size=256,
        callbacks=[early_stop],
        verbose=1
    )
# Out:
# Epoch 1/10
# 125/125 [==============================] - 188s 1s/step - loss: 1.7192 - accuracy: 0.5869 - val_loss: 0.8230 - val_accuracy: 0.7987
# Epoch 2/10
# 125/125 [==============================] - 267s 2s/step - loss: 0.5270 - accuracy: 0.8607 - val_loss: 0.3800 - val_accuracy: 0.8820
# Epoch 3/10
# 125/125 [==============================] - 282s 2s/step - loss: 0.3185 - accuracy: 0.9167 - val_loss: 0.3537 - val_accuracy: 0.8809
# Epoch 4/10
# 125/125 [==============================] - 289s 2s/step - loss: 0.2518 - accuracy: 0.9405 - val_loss: 0.3618 - val_accuracy: 0.8763
# Epoch 5/10
# 125/125 [==============================] - 284s 2s/step - loss: 0.2254 - accuracy: 0.9497 - val_loss: 0.3988 - val_accuracy: 0.8656
# Epoch 6/10
# 125/125 [==============================] - 283s 2s/step - loss: 0.1896 - accuracy: 0.9617 - val_loss: 0.3814 - val_accuracy: 0.8742

# %% [markdown]
# ### BILSTM Training Result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(8, 5))
plt.plot(epochs, acc, 'b-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r--', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(epochs, loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r--', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Matrix Confusion

# %%
loss, acc = bilstm_model.evaluate(xte, y_test, verbose=0)
print("BiLSTM Accuracy:", acc)
# Out:
# BiLSTM Accuracy: 0.8841999769210815

# %%
loss, acc = bilstm_model.evaluate(xte, y_test, verbose=0)
print("BiLSTM Accuracy:", acc)
# Out:
# BiLSTM Accuracy: 0.8841999769210815

# %%
y_bilstm_pred = np.round(bilstm_model.predict(xte, verbose=0) )

# %%
cm = confusion_matrix(y_test, y_bilstm_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.title("BILSTM Confusion Matrix")
plt.show()
